# %%
import random

def deal_card():
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card= random.choice(cards)
    return card

def calculate_score(cards):
    if sum(cards)==21 and len(cards)==2:
        return 0
    if 11 in cards and sum(cards)>21:
        cards.remove(11)
        cards.append(1)
        
    return sum(cards)

def compare(user_score, computer_score):
    if user_score == computer_score:
        return 'Draw'
    elif computer_score==0:
        return "Lose opponent has Blackjack"
    elif user_score ==0:
        return "Win with a Blackjack"
    elif user_score>21:
        return "You went over. You lose"
    elif computer_score>21:
        return "Opponent went over. You win"
    elif user_score > computer_score:
        return "You Win"
    else:
        return "You lose"

    
def play_game():
    user_cards = []
    computer_cards = []
    is_game_over = False

    for _ in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())
    
    while not is_game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)

        print(f"Your cards: {user_cards}, current_Score: {user_score}")
        print(f"Computer cards: {computer_cards[0]}")


        if user_score == 0 or computer_score == 0 or user_score > 21:
            is_game_over = True
        else:
            user_should_deal = input("Type y to get another card, type n to pass:").lower()
            if user_should_deal == 'y':
                user_cards.append(deal_card())
            else:
                is_game_over = True


    while computer_score !=0 and computer_score <17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)
    
    compare(user_score, computer_score)

    print(f"You final hand: {user_cards}, final_score: {user_score}")
    print(f"Computer's final hand: {computer_cards}, final_score: {computer_score}")
    print(compare(user_score, computer_score))
    print("------------------------------------------------------------------------")

while input("Do yo want to play blackjack? Type 'y' or 'n': ").lower() == 'y':
    play_game()
# Out:
# Do yo want to play blackjack? Type 'y' or 'n': y
# Your cards: [7, 11], current_Score: 18
# Computer cards: 2
# Type y to get another card, type n to pass:y
# Your cards: [7, 10, 1], current_Score: 18
# Computer cards: 2
# Type y to get another card, type n to pass:n
# You final hand: [7, 10, 1], final_score: 18
# Computer's final hand: [2, 10, 10], final_score: 22
# Opponent went over. You win
# ------------------------------------------------------------------------
# Do yo want to play blackjack? Type 'y' or 'n': y
# Your cards: [10, 10], current_Score: 20
# Computer cards: 10
# Type y to get another card, type n to pass:n
# You final hand: [10, 10], final_score: 20
# Computer's final hand: [10, 9], final_score: 19
# You Win
# ------------------------------------------------------------------------
